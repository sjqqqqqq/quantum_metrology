# %%
import numpy as np
import matplotlib.pyplot as plt
import glob
from scipy.linalg import sqrtm
from pathlib import Path

def load_npy(root_folder):
    root = Path(root_folder)
    arrays = []

    for file in root.rglob("*.npy"):   # recursively finds all .npy files
        arr = np.load(file)
        arrays.append(arr)

    return arrays
colors = ['blue', 'orange', 'green']

# %% [markdown]
# Small error in Fisher information calculation

# %% [markdown]
# Data Trotter 4

# %%
files_t_4 = glob.glob('C:/Users/alexg/python_scripts/corrected_FI_code/trotter/data_trotter_4/*.npy')
data_t_4 = [np.load(f) for f in files_t_4]
with open('C:/Users/alexg/python_scripts/corrected_FI_code/trotter/data_trotter_4/parameters.txt', "r") as f:
    parameters_data_t_4 = f.read()
print(parameters_data_t_4)
print("Runtime per run (s): ", data_t_4[12])
# Out:
# Parameters: J = 4.5; beta = 1.000; omega = 1; w = [0.1, -0.2, 0.15]; sn_sd = 0.100; delta_t = 0.001; t_steps = 6000; iter = 500; gtol = 1e-05Initial state: theta_scs = 1.571; phi_scs = 0.000; Initial observable = J_y
# Runtime per run (s):  [2938.00974464]

# %%
print("Parameter estimates: ", data_t_4[11])
print("Bias: ", data_t_4[1])
print("Standard deviations: ", data_t_4[13])
print("Infidelity: ", data_t_4[10])
# Out:
# Parameter estimates:  [[ 0.10009821 -0.19980318  0.15004615]]
# Bias:  [[9.82123662e-05 1.96822910e-04 4.61493245e-05]]
# Standard deviations:  [[6.33629358e-07 2.51609311e-06 1.47390084e-06]]
# Infidelity:  [4.14432613e-05]

# %%
data = data_t_4
for i in range(len(data[0])):
    plt.plot(data[9], data[8][i], label='FIM Shannon Entropy')
    plt.plot(data[9], np.full(data[8][i].shape, np.log(3)), label='Max Entropy')
    plt.xlabel('Evolution Time $\Omega t$')
    plt.ylabel('Shannon Entropy')
    plt.legend()
    plt.grid()
    plt.show()

# %% [markdown]
# Data Trotter 6

# %%
files_t_6 = glob.glob('C:/Users/alexg/python_scripts/corrected_FI_code/trotter/data_trotter_6/*.npy')
data_t_6 = [np.load(f) for f in files_t_6]
with open('C:/Users/alexg/python_scripts/corrected_FI_code/trotter/data_trotter_6/parameters.txt', "r") as f:
    parameters_data_t_6 = f.read()
print(parameters_data_t_6)
print("Runtime per run (s): ", data_t_6[12])
# Out:
# Parameters: J = 4.5; beta = 10.000; omega = 1; w = [0.1, -0.2, 0.15]; sn_sd = 0.100; delta_t = 0.001; t_steps = 6000; iter = 500; gtol = 1e-05; Initial state: theta_scs = 1.571; phi_scs = 0.000; Initial observable = J_y
# Runtime per run (s):  [1580.79298782]

# %%
print("Parameter estimates: ", data_t_6[11])
print("Bias: ", data_t_6[1])
print("Standard deviations: ", data_t_6[13])
print("Infidelity: ", data_t_6[10])
# Out:
# Parameter estimates:  [[ 0.09996592 -0.20001301  0.14997515]]
# Bias:  [[-3.40770135e-05 -1.30080982e-05 -2.48530155e-05]]
# Standard deviations:  [[4.45919040e-07 2.18000849e-07 9.54821197e-08]]
# Infidelity:  [0.46977747]

# %% [markdown]
# Data Trotter 8

# %%
files_t_8 = glob.glob('C:/Users/alexg/python_scripts/corrected_FI_code/trotter/data_trotter_8/*.npy')
data_t_8 = [np.load(f) for f in files_t_8]
with open('C:/Users/alexg/python_scripts/corrected_FI_code/trotter/data_trotter_8/parameters.txt', "r") as f:
    parameters_data_t_8 = f.read()
print(parameters_data_t_8)
print("Runtime per run (s): ", data_t_8[12])
# Out:
# Parameters: J = 4.5; beta = 1.000; omega = 1; w = [0.1, -0.2, 0.15]; sn_sd = 0.100; delta_t = 0.001; t_steps = 6000; iter = 500; gtol = 1e-05; Initial state: theta_scs = 1.571; phi_scs = 0.000; Initial observable = J_y
# Runtime per run (s):  [3064.60908341]

# %%
print("Parameter estimates: ", data_t_8[11])
print("Bias: ", data_t_8[1])
print("Standard deviations: ", data_t_8[13])
print("Infidelity: ", data_t_8[10])
print("Fisher: ", data_t_8[6])
# Out:
# Parameter estimates:  [[ 0.10007923 -0.199831    0.150117  ]]
# Bias:  [[7.92306944e-05 1.68995222e-04 1.16999868e-04]]
# Standard deviations:  [[6.65431805e-07 2.74599883e-06 1.56648725e-06]]
# Infidelity:  [0.21290981]
# Fisher:  [[[ 43171636.16925597 -29522243.82757966 -41902210.10785435]
#   [-29522243.82757966  25386498.5658183   18524007.23328728]
#   [-41902210.10785435  18524007.23328728  72601296.39439994]]]

# %%
data = data_t_8
for i in range(len(data[0])):
    plt.plot(data[9], data[8][i], label='FIM Shannon Entropy')
    plt.plot(data[9], np.full(data[8][i].shape, np.log(3)), label='Max Entropy')
    plt.xlabel('Evolution Time $\Omega t$')
    plt.ylabel('Shannon Entropy')
    plt.legend()
    plt.grid()
    plt.show()

# %% [markdown]
# Data Trotter 9

# %%
files_t_9 = glob.glob('C:/Users/alexg/python_scripts/corrected_FI_code/trotter/data_trotter_9/*.npy')
data_t_9 = [np.load(f) for f in files_t_9]
with open('C:/Users/alexg/python_scripts/corrected_FI_code/trotter/data_trotter_9/parameters.txt', "r") as f:
    parameters_data_t_9 = f.read()
print(parameters_data_t_9)
print("Runtime per run (s): ", data_t_9[12])
# Out:
# Parameters: J = 4.5; beta = 0.100; omega = 1; w = [0.1, -0.2, 0.15]; sn_sd = 0.100; delta_t = 0.001; t_steps = 6000; iter = 500; gtol = 1e-05; Initial state: theta_scs = 1.571; phi_scs = 0.000; Initial observable = J_y
# Runtime per run (s):  [17475.71831989]

# %%
print("Parameter estimates: ", data_t_9[11])
print("Bias: ", data_t_9[1])
print("Standard deviations: ", data_t_9[13])
print("Infidelity: ", data_t_9[10])
# Out:
# Parameter estimates:  [[0.08919907 0.51994599 0.16102852]]
# Bias:  [[-0.01080093  0.71994599  0.01102852]]
# Standard deviations:  [[5.98853631e-07 2.15367904e-06 3.74498243e-07]]
# Infidelity:  [0.19038914]

# %%
FIM = data_t_9[6]
FIM_inv = np.linalg.inv(FIM)
FIM_eig = np.linalg.eigvals(FIM)
print("Fisher Matrix: ", FIM)
print("Fisher Matrix Eigenvalues: ", FIM_eig)
print("Fisher Matrix Inverse: ", FIM_inv)
print("Covariance Matrix: ", data_t_9[2])
# Out:
# Fisher Matrix:  [[[ 3.01026393e+07 -2.31930726e+07 -4.43078469e+07]
#   [-2.31930726e+07  1.83322757e+07  3.08515108e+07]
#   [-4.43078469e+07  3.08515108e+07  1.16750433e+08]]]
# Fisher Matrix Eigenvalues:  [[1.46393190e+08 1.43903552e+05 1.86482547e+07]]
# Fisher Matrix Inverse:  [[[3.02526396e-06 3.41307228e-06 2.46204618e-07]
#   [3.41307228e-06 3.94882836e-06 2.51806888e-07]
#   [2.46204618e-07 2.51806888e-07 3.54617408e-08]]]
# Covariance Matrix:  [[[ 5.98853631e-07  1.10649561e-06 -4.32597321e-07]
#   [ 1.10649561e-06  2.15367904e-06 -7.84636629e-07]
#   [-4.32597321e-07 -7.84636629e-07  3.74498243e-07]]]

# %%
data = data_t_9
for i in range(len(data[0])):
    plt.plot(data[9], data[8][i], label='FIM Shannon Entropy')
    plt.plot(data[9], np.full(data[8][i].shape, np.log(3)), label='Max Entropy')
    plt.xlabel('Evolution Time $\Omega t$')
    plt.ylabel('Shannon Entropy')
    plt.legend()
    plt.grid()
    plt.show()

# %% [markdown]
# End small error in Fisher information calculation

# %% [markdown]
# Data Trotter 3

# %%
files_t_3 = glob.glob('C:/Users/alexg/python_scripts/corrected_FI_code/trotter/data_trotter_3/*.npy')
data_t_3 = [np.load(f) for f in files_t_3]
with open('C:/Users/alexg/python_scripts/corrected_FI_code/trotter/data_trotter_3/parameters.txt', "r") as f:
    parameters_data_t_3 = f.read()
print(parameters_data_t_3)
print("Runtime per run (s): ", data_t_3[12])
# Out:
# Parameters: J = 4.5; beta = 10.000; omega = 1; w = [0.03455842 0.08216181 0.03304371]; sn_sd = 0.100; delta_t = 0.001; t_steps = 6000; iter = 500; gtol = 1e-05; Initial state: theta_scs = 1.571; phi_scs = 0.000; Initial observable = J_y
# Runtime per run (s):  [2865.17260838 2498.5857091   548.54456306 1958.46977043]

# %%
files_t_11 = glob.glob('C:/Users/alexg/python_scripts/corrected_FI_code/trotter/data_trotter_11/*.npy')
data_t_11 = [np.load(f) for f in files_t_11]
with open('C:/Users/alexg/python_scripts/corrected_FI_code/trotter/data_trotter_11/parameters.txt', "r") as f:
    parameters_data_t_11 = f.read()
print(parameters_data_t_11)
print("Runtime per run (s): ", data_t_11[13])
# Out:
# Parameters: J = 4.5; beta = 9.000; omega = 1; w = [0.03455842, 0.08216181, 0.03304371]; sn_sd = 0.100; delta_t = 0.001; t_steps = 6000; iter = 500; gtol = 1e-05; Initial state: theta_scs = 1.571; phi_scs = 0.000; Initial observable = J_y
# Runtime per run (s):  [ 474.61011195  664.11160374 1595.42635298 1019.82050204  768.03055382
#   976.14703441 1148.62358236 1442.91219163]

# %%
data = data_t_3
plt.plot(data[0],data[10], marker = 'o')
plt.semilogy()
#plt.semilogx()
plt.xlabel("Beta")
plt.ylabel("Infidelity")
plt.title("Infidelity between inverse of Fisher information and covariance matrix")
plt.grid()
plt.show()

plt.plot(data[0], data[7], marker = 'o')
plt.semilogy()
#plt.semilogx()
plt.xlabel("Beta")
plt.ylabel("Trace difference")
plt.title("Trace of inverse of Fisher information matrix")
plt.grid()
plt.show()

plt.plot(data[0], np.log(np.linalg.det(data[6])), marker = 'o')
plt.semilogy()
#plt.semilogx()
plt.xlabel("Beta")
plt.ylabel("Log Determinant")
plt.title("Log of determinant of Fisher information matrix")
plt.grid()
plt.show()

for i in range(data[1].shape[1]):
    plt.errorbar(data[0], data[1][:,i], yerr = data[13][:,i], label = f"Bias for $\omega_{i+1}$", marker = 'o')
#plt.semilogx()
plt.xlabel("Runs")
plt.ylabel("Bias")
plt.title("Estimator bias")
plt.legend()
plt.grid()
plt.show()

plt.plot(data[0][:], data[3][:] + np.linalg.norm(data[1][:], axis=1)**2, marker = 'o')
plt.xlabel("Beta")
plt.ylabel("MSE")
plt.semilogy()
plt.title("Mean Squared Error (MSE) vs Beta")
plt.grid()
plt.show()

for i in range(len(data[0])):
    plt.plot(data[9], data[8][i], label='FIM Shannon Entropy')
    plt.plot(data[9], np.full(data[8][i].shape, np.log(3)), label='Max Entropy')
    plt.title(f"Beta = {data[0][i]:.2f}")
    plt.xlabel('Evolution Time $\Omega t$')
    plt.ylabel('Shannon Entropy')
    plt.legend()
    plt.grid()
    plt.show()

# %%
beta = np.concatenate([data_t_3[0][:3], data_t_11[0], data_t_3[0][3:]])
infidelity = np.concatenate([data_t_3[10][:3], data_t_11[10], data_t_3[10][3:]])
fish_inv_trace = np.concatenate([data_t_3[7][:3], data_t_11[7], data_t_3[7][3:]])
fish_inv = np.concatenate([data_t_3[6][:3], data_t_11[6], data_t_3[6][3:]])
bias = np.concatenate([data_t_3[1][:3], data_t_11[1], data_t_3[1][3:]])
std = np.concatenate([data_t_3[13][:3], data_t_11[14], data_t_3[13][3:]])
mse = np.concatenate([data_t_3[3][:3] + np.linalg.norm(data_t_3[1][:3], axis=1)**2, np.sum(data_t_11[12],axis = 1),  data_t_3[3][3:] + np.linalg.norm(data_t_3[1][3:], axis=1)**2])
crb = np.concatenate([data_t_3[4][:3], data_t_11[4], data_t_3[4][3:]])
cov_trace = np.concatenate([data_t_3[3][:3], data_t_11[3], data_t_3[3][3:]])
plt.plot(beta, infidelity, marker = 'o')
plt.semilogy()
#plt.semilogx()
plt.xlabel("Beta")
plt.ylabel("Infidelity")
plt.title("Infidelity between inverse of Fisher information and covariance matrix")
plt.grid()
plt.show()

plt.plot(beta, fish_inv_trace, marker = 'o')
plt.semilogy()
#plt.semilogx()
plt.xlabel("Beta")
plt.ylabel("Trace")
plt.title("Trace of inverse of Fisher information matrix")
plt.grid()
plt.show()

# plt.plot(beta, cov_trace - fish_inv_trace, marker = 'o')
# plt.semilogy()
# #plt.semilogx()
# plt.xlabel("Beta")
# plt.ylabel("Trace")
# plt.title("Trace of covariance matrix minus inverse of Fisher information matrix")
# plt.grid()
# plt.show()

# plt.plot(beta, crb, marker = 'o')
# plt.semilogy()
# #plt.semilogx()
# plt.xlabel("Beta")
# plt.ylabel("Eigenvalues")
# plt.title("Eigenvalues of covariance matrix minus inverse of Fisher information matrix")
# plt.grid()
# plt.show()

plt.plot(beta, np.log(np.linalg.det(fish_inv)), marker = 'o')
plt.semilogy()
#plt.semilogx()
plt.xlabel("Beta")
plt.ylabel("Log Determinant")
plt.title("Log of determinant of Fisher information matrix")
plt.grid()
plt.show()

for i in range(data_t_11[1].shape[1]):
    plt.errorbar(beta, bias[:,i], yerr = std[:,i], label = f"Bias for $\omega_{i+1}$", marker = 'o')
#plt.semilogx()
plt.xlabel("Beta")
plt.ylabel("Bias")
plt.title("Estimator bias")
plt.legend()
plt.grid()
plt.show()

plt.plot(beta, mse, marker = 'o')
plt.xlabel("Beta")
plt.ylabel("MSE")
plt.semilogy()
plt.title("Mean Squared Error (MSE) vs Beta")
plt.grid()
plt.show()

for i in range(len(data_t_11[0])):
    plt.plot(data_t_11[9], data_t_11[8][i], label='FIM Shannon Entropy')
    plt.plot(data_t_11[9], np.full(data_t_11[8][i].shape, np.log(3)), label='Max Entropy')
    plt.title(f"Beta = {data_t_11[0][i]:.2f}")
    plt.xlabel('Evolution Time $\Omega t$')
    plt.ylabel('Shannon Entropy')
    plt.legend()
    plt.grid()
    plt.show()

# %%
for i in range(data[1].shape[0]):
    print(data[1][i])
print("w_true = [0.03455842 0.08216181 0.03304371]")
# Out:
# [-0.06637937 -0.21916073 -0.00118756]
# [-1.46548979e-03 -1.85406837e-03  1.65673710e-05]
# [3.61969379e-05 5.37344412e-05 5.12803964e-05]
# [ 2.93403338e-05 -2.56368590e-06  1.18684198e-05]
# w_true = [0.03455842 0.08216181 0.03304371]

# %%
for i in range(len(data[10])):
    print(data[10][i])
# Out:
# 0.16520614816032742
# 0.00273994712946668
# 0.0006631162507247934
# 0.009400178826181493

# %%
cov_max = np.max(np.linalg.eigvals(data[2][0]))
fish_max = np.max(np.linalg.eigvals(np.linalg.inv(data[6][0])))
print(cov_max, fish_max)
print(data[4][0,0])
# Out:
# 0.0003317458441968831 0.00031454695571343604
# -0.00012361233739397598

# %%
np.linalg.norm(data[1], axis=1)**2 + data[3]
# Out:
# array([5.27718016e-02, 1.73186688e-04, 1.44569935e-06, 1.23038691e-07])

# %%
print(data[3])
# Out:
# [3.32744308e-04 1.67601184e-04 1.43887206e-06 1.22030404e-07]

# %%
MSE = np.array([[data[1][i][k]**2 + data[13][i][k] for k in range(3)] for i in range(4)])

# %%
print(np.sum(MSE, axis=1))
# Out:
# [5.27718016e-02 1.73186688e-04 1.44569935e-06 1.23038691e-07]

# %% [markdown]
# Data Trotter 10 (Omega = 0, Beta = 0)

# %%
files_t_10 = glob.glob('C:/Users/alexg/python_scripts/corrected_FI_code/trotter/data_trotter_10/*.npy')
data_t_10 = [np.load(f) for f in files_t_10]
with open('C:/Users/alexg/python_scripts/corrected_FI_code/trotter/data_trotter_10/parameters.txt', "r") as f:
    parameters_data_t_10 = f.read()
print(parameters_data_t_10)
print("Runtime per run (s): ", data_t_10[13])
# Out:
# Parameters: J = 4.5; beta = 0.000; omega = 0; w = [0.03455842 0.08216181 0.03304371]; sn_sd = 0.100; delta_t = 0.001; t_steps = 6000; iter = 500; gtol = 1e-05; Initial state: theta_scs = 1.571; phi_scs = 0.000; Initial observable = J_y
# Runtime per run (s):  [2504.68032932]

# %%
print("Parameter estimates: ", data_t_10[11])
print("Bias: ", data_t_10[1])
print("Standard deviations: ", data_t_10[14])
print("Infidelity: ", data_t_10[10])
print("MSE: ", data_t_10[12])
print("Fisher: ", data_t_10[6])
# Out:
# Parameter estimates:  [[-0.04184248 -0.07899991  0.03292063]]
# Bias:  [[-7.64008970e-02 -1.61161723e-01 -1.23082095e-04]]
# Standard deviations:  [[3.34501361e-04 1.12592770e-03 3.51040228e-07]]
# Infidelity:  [0.13564387]
# MSE:  [[6.17159842e-03 2.70990287e-02 3.66189430e-07]]
# Fisher:  [[[4.60160077e+06 1.45083024e+06 2.40342710e+07]
#   [1.45083024e+06 4.59322753e+05 7.69375172e+06]
#   [2.40342710e+07 7.69375172e+06 1.34196516e+08]]]

# %%
data = data_t_10
for i in range(len(data[0])):
    plt.plot(data[9], data[8][i], label='FIM Shannon Entropy')
    plt.plot(data[9], np.full(data[8][i].shape, np.log(3)), label='Max Entropy')
    plt.xlabel('Evolution Time $\Omega t$')
    plt.ylabel('Shannon Entropy')
    plt.legend()
    plt.grid()
    plt.show()

# %% [markdown]
# Data Trotter 12 (magnetic field pointing mostly along x)

# %%
files_t_12_x = glob.glob('C:/Users/alexg/python_scripts/corrected_FI_code/trotter/data_trotter_12_x/*.npy')
data_t_12_x = [np.load(f) for f in files_t_12_x]
with open('C:/Users/alexg/python_scripts/corrected_FI_code/trotter/data_trotter_12_x/parameters.txt', "r") as f:
    parameters_data_t_12_x = f.read()
print(parameters_data_t_12_x)
print("Runtime per run (s): ", data_t_12_x[13])
# Out:
# Parameters: J = 4.5; beta = 10.000; omega = 1; w = [ 1.07277391e-01  4.15382853e-05 -6.15468116e-03]; sn_sd = 0.100; delta_t = 0.001; t_steps = 6000; iter = 500; gtol = 1e-05; Initial state: theta_scs = 1.571; phi_scs = 0.000; Initial observable = J_y
# Runtime per run (s):  [ 1218.90296078  1081.19168019  2104.77091217   882.61125708
#   1332.99185514  1193.33017302   991.23049951  1239.43091965
#  12836.21068645  1126.70409513  2107.45599246]

# %%
data = data_t_12_x
plt.plot(data[0], data[10], marker = 'o')
plt.semilogy()
#plt.semilogx()
plt.xlabel("Beta")
plt.ylabel("Infidelity")
plt.title("Infidelity between inverse of Fisher information and covariance matrix")
plt.grid()
plt.show()

plt.plot(data[0], data[7], marker = 'o')
plt.semilogy()
#plt.semilogx()
plt.xlabel("Beta")
plt.ylabel("Trace")
plt.title("Trace of inverse of Fisher information matrix")
plt.grid()
plt.show()

# plt.plot(data[0], data[7] - data[3], marker = 'o')
# plt.semilogy()
# #plt.semilogx()
# plt.xlabel("Beta")
# plt.ylabel("Trace")
# plt.title("Trace of covariance matrix minus inverse of Fisher information matrix")
# plt.grid()
# plt.show()

# plt.plot(data[0], data[4], marker = 'o')
# plt.semilogy()
# #plt.semilogx()
# plt.xlabel("Beta")
# plt.ylabel("Eigenvalues")
# plt.title("Eigenvalues of covariance matrix minus inverse of Fisher information matrix")
# plt.grid()
# plt.show()

plt.plot(data[0], np.log(np.linalg.det(data[6])), marker = 'o')
plt.semilogy()
#plt.semilogx()
plt.xlabel("Beta")
plt.ylabel("Log Determinant")
plt.title("Log of determinant of Fisher information matrix")
plt.grid()
plt.show()

for i in range(data[1].shape[1]):
    plt.errorbar(data[0], data[1][:,i], yerr = data[14][:,i], label = f"Bias for $\omega_{i+1}$", marker = 'o')
#plt.semilogx()
plt.xlabel("Beta")
plt.ylabel("Bias")
plt.title("Estimator bias")
plt.legend()
plt.grid()
plt.show()

plt.plot(data[0], np.sum(data[12], axis=1), marker = 'o')
plt.xlabel("Beta")
plt.ylabel("MSE")
plt.semilogy()
plt.title("Mean Squared Error (MSE) vs Beta")
plt.grid()
plt.show()

for i in range(len(data[0])):
    plt.plot(data[9], data[8][i], label='FIM Shannon Entropy')
    plt.plot(data[9], np.full(data[8][i].shape, np.log(3)), label='Max Entropy')
    plt.title(f"Beta = {data[0][i]:.2f}")
    plt.xlabel('Evolution Time $\Omega t$')
    plt.ylabel('Shannon Entropy')
    plt.legend()
    plt.grid()
    plt.show()

# %% [markdown]
# Data trotter 12 ( magnetic field pointing mostly along z)

# %%
files_t_12_z = glob.glob('C:/Users/alexg/python_scripts/corrected_FI_code/trotter/data_trotter_12_z/*.npy')
data_t_12_z = [np.load(f) for f in files_t_12_z]
with open('C:/Users/alexg/python_scripts/corrected_FI_code/trotter/data_trotter_12_z/parameters.txt', "r") as f:
    parameters_data_t_12_z = f.read()
print(parameters_data_t_12_z)
print("Runtime per run (s): ", data_t_12_z[13])
# Out:
# Parameters: J = 4.5; beta = 10.000; omega = 1; w = [0.00686906 0.01295031 0.09800078]; sn_sd = 0.100; delta_t = 0.001; t_steps = 6000; iter = 500; gtol = 1e-05; Initial state: theta_scs = 1.571; phi_scs = 0.000; Initial observable = J_y
# Runtime per run (s):  [ 3280.0240891   1554.09013987 12170.86427712  1234.87615347
#   1198.32300019  1764.2723701   3256.90020895   888.65287375
#    756.68990636  1452.85255718  1313.03697705]

# %%
data = data_t_12_z
plt.plot(data[0], data[10], marker = 'o')
plt.semilogy()
#plt.semilogx()
plt.xlabel("Beta")
plt.ylabel("Infidelity")
plt.title("Infidelity between inverse of Fisher information and covariance matrix")
plt.grid()
plt.show()

plt.plot(data[0], data[7], marker = 'o')
plt.semilogy()
#plt.semilogx()
plt.xlabel("Beta")
plt.ylabel("Trace")
plt.title("Trace of inverse of Fisher information matrix")
plt.grid()
plt.show()

# plt.plot(data[0], data[7] - data[3], marker = 'o')
# plt.semilogy()
# #plt.semilogx()
# plt.xlabel("Beta")
# plt.ylabel("Trace")
# plt.title("Trace of covariance matrix minus inverse of Fisher information matrix")
# plt.grid()
# plt.show()

# plt.plot(data[0], data[4], marker = 'o')
# plt.semilogy()
# #plt.semilogx()
# plt.xlabel("Beta")
# plt.ylabel("Eigenvalues")
# plt.title("Eigenvalues of covariance matrix minus inverse of Fisher information matrix")
# plt.grid()
# plt.show()

plt.plot(data[0], np.log(np.linalg.det(data[6])), marker = 'o')
plt.semilogy()
#plt.semilogx()
plt.xlabel("Beta")
plt.ylabel("Log Determinant")
plt.title("Log of determinant of Fisher information matrix")
plt.grid()
plt.show()

for i in range(data[1].shape[1]):
    plt.errorbar(data[0], data[1][:,i], yerr = data[14][:,i], label = f"Bias for $\omega_{i+1}$", marker = 'o')
#plt.semilogx()
plt.xlabel("Beta")
plt.ylabel("Bias")
plt.title("Estimator bias")
plt.legend()
plt.grid()
plt.show()

plt.plot(data[0], np.sum(data[12], axis=1), marker = 'o')
plt.xlabel("Beta")
plt.ylabel("MSE")
plt.semilogy()
plt.title("Mean Squared Error (MSE) vs Beta")
plt.grid()
plt.show()

for i in range(len(data[0])):
    plt.plot(data[9], data[8][i], label='FIM Shannon Entropy')
    plt.plot(data[9], np.full(data[8][i].shape, np.log(3)), label='Max Entropy')
    plt.title(f"Beta = {data[0][i]:.2f}")
    plt.xlabel('Evolution Time $\Omega t$')
    plt.ylabel('Shannon Entropy')
    plt.legend()
    plt.grid()
    plt.show()

# %% [markdown]
# Data trotter 13 (Beta from 20 to 90)

# %%
files_t_13 = glob.glob('C:/Users/alexg/python_scripts/corrected_FI_code/trotter/data_trotter_13/*.npy')
data_t_13 = [np.load(f) for f in files_t_13]
with open('C:/Users/alexg/python_scripts/corrected_FI_code/trotter/data_trotter_13/parameters.txt', "r") as f:
    parameters_data_t_13 = f.read()
print(parameters_data_t_13)
print("Runtime per run (s): ", data_t_13[13])
# Out:
# Parameters: J = 4.5; beta = 90.000; omega = 1; w = [0.01371326 0.00298802 0.13318164]; sn_sd = 0.100; delta_t = 0.001; t_steps = 6000; iter = 500; gtol = 1e-05; Initial state: theta_scs = 1.571; phi_scs = 0.000; Initial observable = J_y
# Runtime per run (s):  [ 3361.66354847  2077.06584787  2545.11058831  3461.78723526
#   3852.68959236  2128.12155461 16916.23690796  2204.09854293]

# %%
data = data_t_13
plt.plot(data[0], data[10], marker = 'o')
plt.semilogy()
#plt.semilogx()
plt.xlabel("Beta")
plt.ylabel("Infidelity")
plt.title("Infidelity between inverse of Fisher information and covariance matrix")
plt.grid()
plt.show()

plt.plot(data[0], data[7], marker = 'o')
plt.semilogy()
#plt.semilogx()
plt.xlabel("Beta")
plt.ylabel("Trace")
plt.title("Trace of inverse of Fisher information matrix")
plt.grid()
plt.show()

plt.plot(data[0], data[7] - data[3], marker = 'o')
#plt.semilogy()
#plt.semilogx()
plt.xlabel("Beta")
plt.ylabel("Trace")
plt.title("Trace of covariance matrix minus inverse of Fisher information matrix")
plt.grid()
plt.show()

plt.plot(data[0], data[4], marker = 'o')
#plt.semilogy()
#plt.semilogx()
plt.xlabel("Beta")
plt.ylabel("Eigenvalues")
plt.title("Eigenvalues of covariance matrix minus inverse of Fisher information matrix")
plt.grid()
plt.show()

plt.plot(data[0], np.log(np.linalg.det(data[6])), marker = 'o')
plt.semilogy()
#plt.semilogx()
plt.xlabel("Beta")
plt.ylabel("Log Determinant")
plt.title("Log of determinant of Fisher information matrix")
plt.grid()
plt.show()

for i in range(data[1].shape[1]):
    plt.errorbar(data[0], data[1][:,i], yerr = data[14][:,i], label = f"Bias for $\omega_{i+1}$", marker = 'o')
#plt.semilogx()
plt.xlabel("Beta")
plt.ylabel("Bias")
plt.title("Estimator bias")
plt.legend()
plt.grid()
plt.show()

plt.plot(data[0], np.sum(data[12], axis=1), marker = 'o')
plt.xlabel("Beta")
plt.ylabel("MSE")
plt.semilogy()
plt.title("Mean Squared Error (MSE) vs Beta")
plt.grid()
plt.show()

# for i in range(len(data[0])):
#     plt.plot(data[9], data[8][i], label='FIM Shannon Entropy')
#     plt.plot(data[9], np.full(data[8][i].shape, np.log(3)), label='Max Entropy')
#     plt.title(f"Beta = {data[0][i]:.2f}")
#     plt.xlabel('Evolution Time $\Omega t$')
#     plt.ylabel('Shannon Entropy')
#     plt.legend()
#     plt.grid()
#     plt.show()

# %% [markdown]
# Data trotter 14 (Random phases switch every 100 time steps)

# %%
files_t_14 = glob.glob('C:/Users/alexg/python_scripts/corrected_FI_code/trotter/data_trotter_14/*.npy')
data_t_14 = [np.load(f) for f in files_t_14]
with open('C:/Users/alexg/python_scripts/corrected_FI_code/trotter/data_trotter_14/parameters.txt', "r") as f:
    parameters_data_t_14 = f.read()
print(parameters_data_t_14)
print("Runtime per run (s): ", data_t_14[13])
# Out:
# Parameters: J = 4.5; beta = 10.000; omega = 1; w = [0.03455842 0.08216181 0.03304371]; sn_sd = 0.100; delta_t = 0.001; t_steps = 7000; iter = 500; random_phase_steps = 100;  gtol = 1e-05; Initial state: theta_scs = 1.571; phi_scs = 0.000; Initial observable = J_y
# Runtime per run (s):  [2889.23210835 2426.81693316 2453.1862731  2393.23515582 2761.98345065
#  3711.45398426 7332.41421437 3048.11421204 3125.67022276 3897.8058784
#  2328.13237834]

# %%
data = data_t_14
plt.plot(data[0], data[10], marker = 'o')
plt.semilogy()
#plt.semilogx()
plt.xlabel("Beta")
plt.ylabel("Infidelity")
plt.title("Infidelity between inverse of Fisher information and covariance matrix")
plt.grid()
plt.show()

plt.plot(data[0], data[7], marker = 'o')
plt.semilogy()
#plt.semilogx()
plt.xlabel("Beta")
plt.ylabel("Trace")
plt.title("Trace of inverse of Fisher information matrix")
plt.grid()
plt.show()

plt.plot(data[0], data[3] - data[7], marker = 'o')
#plt.semilogy()
#plt.semilogx()
plt.xlabel("Beta")
plt.ylabel("Trace")
plt.title("Trace of covariance matrix minus inverse of Fisher information matrix")
plt.grid()
plt.show()

plt.plot(data[0], data[4], marker = 'o')
#plt.semilogy()
#plt.semilogx()
plt.xlabel("Beta")
plt.ylabel("Eigenvalues")
plt.title("Eigenvalues of covariance matrix minus inverse of Fisher information matrix")
plt.grid()
plt.show()

plt.plot(data[0], np.log(np.linalg.det(data[6])), marker = 'o')
plt.semilogy()
#plt.semilogx()
plt.xlabel("Beta")
plt.ylabel("Log Determinant")
plt.title("Log of determinant of Fisher information matrix")
plt.grid()
plt.show()

for i in range(data[1].shape[1]):
    plt.errorbar(data[0], data[1][:,i], yerr = data[14][:,i], label = f"Bias for $\omega_{i+1}$", marker = 'o')
#plt.semilogx()
plt.xlabel("Beta")
plt.ylabel("Bias")
plt.title("Estimator bias")
plt.legend()
plt.grid()
plt.show()

plt.plot(data[0], np.sum(data[12], axis=1), marker = 'o')
plt.xlabel("Beta")
plt.ylabel("MSE")
plt.semilogy()
plt.title("Mean Squared Error (MSE) vs Beta")
plt.grid()
plt.show()

# for i in range(len(data[0])):
#     plt.plot(data[9], data[8][i], label='FIM Shannon Entropy')
#     plt.plot(data[9], np.full(data[8][i].shape, np.log(3)), label='Max Entropy')
#     plt.title(f"Beta = {data[0][i]:.2f}")
#     plt.xlabel('Evolution Time $\Omega t$')
#     plt.ylabel('Shannon Entropy')
#     plt.legend()
#     plt.grid()
#     plt.show()

# %% [markdown]
# Data trotter 15 (Random phases every 1000 time steps)

# %%
files_t_15 = glob.glob('C:/Users/alexg/python_scripts/corrected_FI_code/trotter/data_trotter_15/*.npy')
data_t_15 = [np.load(f) for f in files_t_15]
with open('C:/Users/alexg/python_scripts/corrected_FI_code/trotter/data_trotter_15/parameters.txt', "r") as f:
    parameters_data_t_15 = f.read()
print(parameters_data_t_15)
print("Runtime per run (s): ", data_t_15[13])
# Out:
# Parameters: J = 4.5; beta = 10.000; omega = 1; w = [0.03455842 0.08216181 0.03304371]; sn_sd = 0.100; delta_t = 0.001; t_steps = 7000; iter = 500; random_phase_steps = 1000;  gtol = 1e-05; Initial state: theta_scs = 1.571; phi_scs = 0.000; Initial observable = J_y
# Runtime per run (s):  [ 1361.53361773  1517.0546124  24978.49125552  4616.57942533
#   2561.59329247  2356.2180686   4745.64271736  3629.11115241
#   2599.18841958  2971.71901298  3665.55394673]

# %%
data = data_t_15
plt.plot(data[0], data[10], marker = 'o')
plt.semilogy()
#plt.semilogx()
plt.xlabel("Beta")
plt.ylabel("Infidelity")
plt.title("Infidelity between inverse of Fisher information and covariance matrix")
plt.grid()
plt.show()

plt.plot(data[0], data[7], marker = 'o')
plt.semilogy()
#plt.semilogx()
plt.xlabel("Beta")
plt.ylabel("Trace")
plt.title("Trace of inverse of Fisher information matrix")
plt.grid()
plt.show()

plt.plot(data[0], data[3] - data[7], marker = 'o')
#plt.semilogy()
#plt.semilogx()
plt.xlabel("Beta")
plt.ylabel("Trace")
plt.title("Trace of covariance matrix minus trace of inverse of Fisher information matrix")
plt.grid()
plt.show()

plt.plot(data[0], data[4], marker = 'o')
#plt.semilogy()
#plt.semilogx()
plt.xlabel("Beta")
plt.ylabel("Eigenvalues")
plt.title("Eigenvalues of covariance matrix minus inverse of Fisher information matrix")
plt.grid()
plt.show()

plt.plot(data[0], np.log(np.linalg.det(data[6])), marker = 'o')
plt.semilogy()
#plt.semilogx()
plt.xlabel("Beta")
plt.ylabel("Log Determinant")
plt.title("Log of determinant of Fisher information matrix")
plt.grid()
plt.show()

for i in range(data[1].shape[1]):
    plt.errorbar(data[0], data[1][:,i], yerr = data[14][:,i], label = f"Bias for $\omega_{i+1}$", marker = 'o')
#plt.semilogx()
plt.xlabel("Beta")
plt.ylabel("Bias")
plt.title("Estimator bias")
plt.legend()
plt.grid()
plt.show()

plt.plot(data[0], np.sum(data[12], axis=1), marker = 'o')
plt.xlabel("Beta")
plt.ylabel("MSE")
plt.semilogy()
plt.title("Mean Squared Error (MSE) vs Beta")
plt.grid()
plt.show()

# for i in range(len(data[0])):
#     plt.plot(data[9], data[8][i], label='FIM Shannon Entropy')
#     plt.plot(data[9], np.full(data[8][i].shape, np.log(3)), label='Max Entropy')
#     plt.title(f"Beta = {data[0][i]:.2f}")
#     plt.xlabel('Evolution Time $\Omega t$')
#     plt.ylabel('Shannon Entropy')
#     plt.legend()
#     plt.grid()
#     plt.show()

# %% [markdown]
# Data protocol A (random states)

# %%
files_a_rand_1 = glob.glob('C:/Users/alexg/python_scripts/corrected_FI_code/protocol_A/data_protocol_A_rand_1/*.npy')
data_a_rand_1 = [np.load(f) for f in files_a_rand_1]
with open('C:/Users/alexg/python_scripts/corrected_FI_code/trotter/data_trotter_15/parameters.txt', "r") as f:
    parameters_data_a_rand_1 = f.read()
print(parameters_data_a_rand_1)
print("Runtime per run (s): ", data_a_rand_1[11])
# Out:
# Parameters: J = 4.5; beta = 10.000; omega = 1; w = [0.03455842 0.08216181 0.03304371]; sn_sd = 0.100; delta_t = 0.001; t_steps = 7000; iter = 500; random_phase_steps = 1000;  gtol = 1e-05; Initial state: theta_scs = 1.571; phi_scs = 0.000; Initial observable = J_y
# Runtime per run (s):  [1153.67371011  655.28850746  415.40649986  411.93226743  352.01860571
#   391.04186463  377.29045415  457.63338065  419.91762161]

# %%
data = data_a_rand_1
plt.plot(data[10], data[4], marker = 'o')
plt.semilogy()
#plt.semilogx()
plt.xlabel("Number of states")
plt.ylabel("Infidelity")
plt.title("Infidelity between inverse of Fisher information and covariance matrix")
plt.grid()
plt.show()

plt.plot(data[10], data[6], marker = 'o')
plt.semilogy()
#plt.semilogx()
plt.xlabel("Number of states")
plt.ylabel("Trace")
plt.title("Trace of inverse of Fisher information matrix")
plt.grid()
plt.show()

plt.plot(data[10], data[2] - data[6], marker = 'o')
#plt.semilogy()
#plt.semilogx()
plt.xlabel("Number of states")
plt.ylabel("Trace")
plt.title("Trace of covariance matrix minus trace of inverse of Fisher information matrix")
plt.grid()
plt.show()

plt.plot(data[10], data[3], marker = 'o')
#plt.semilogy()
#plt.semilogx()
plt.xlabel("Number of states")
plt.ylabel("Eigenvalues")
plt.title("Eigenvalues of covariance matrix minus inverse of Fisher information matrix")
plt.grid()
plt.show()

plt.plot(data[10], np.log(np.linalg.det(data[5])), marker = 'o')
plt.semilogy()
#plt.semilogx()
plt.xlabel("Number of states")
plt.ylabel("Log Determinant")
plt.title("Log of determinant of Fisher information matrix")
plt.grid()
plt.show()

for i in range(data[0].shape[1]):
    plt.errorbar(data[10], data[0][:,i], yerr = data[12][:,i], label = f"Bias for $\omega_{i+1}$", marker = 'o')
#plt.semilogx()
plt.xlabel("Number of states")
plt.ylabel("Bias")
plt.title("Estimator bias")
plt.legend()
plt.grid()
plt.show()

plt.plot(data[10], data[2] + np.linalg.norm(data[0], axis=1)**2, marker = 'o')
plt.xlabel("Number of states")
plt.ylabel("MSE")
plt.semilogy()
plt.title("Mean Squared Error (MSE) vs Number of States")
plt.grid()
plt.show()

# for i in range(len(data[10])):
#     plt.plot(data[8], data[7][i], label='FIM Shannon Entropy')
#     plt.plot(data[8], np.full(data[7][i].shape, np.log(3)), label='Max Entropy')
#     plt.title(f"Number of states = {data[10][i]}")
#     plt.xlabel('Evolution Time $\Omega t$')
#     plt.ylabel('Shannon Entropy')
#     plt.legend()
#     plt.grid()
#     plt.show()

# %% [markdown]
# Data protocol A (fibonacci states)

# %%
files_a_fib_1 = glob.glob('C:/Users/alexg/python_scripts/corrected_FI_code/protocol_A/data_protocol_A_fib_1/*.npy')
data_a_fib_1 = [np.load(f) for f in files_a_fib_1]
with open('C:/Users/alexg/python_scripts/corrected_FI_code/trotter/protocol_A/data_protocol_A_fib_1/parameters.txt', "r") as f:
    parameters_data_a_fib_1 = f.read()
print(parameters_data_a_fib_1)
print("Runtime per run (s): ", data_a_fib_1[11])
# Out:
# Parameters: J = 4.5; beta = 10.000; omega = 1; w = [0.03455842 0.08216181 0.03304371]; sn_sd = 0.100; delta_t = 0.001; t_steps = 7000; iter = 500; random_phase_steps = 1000;  gtol = 1e-05; Initial state: theta_scs = 1.571; phi_scs = 0.000; Initial observable = J_y
# Runtime per run (s):  [1301.21846294  766.76431918  576.2239387   510.83098102  399.50640607
#   445.90682077  518.41752481  449.18193293  461.63562131]

# %%
data = data_a_fib_1
plt.plot(data[10], data[4], marker = 'o')
plt.semilogy()
#plt.semilogx()
plt.xlabel("Number of states")
plt.ylabel("Infidelity")
plt.title("Infidelity between inverse of Fisher information and covariance matrix")
plt.grid()
plt.show()

plt.plot(data[10], data[6], marker = 'o')
plt.semilogy()
#plt.semilogx()
plt.xlabel("Number of states")
plt.ylabel("Trace")
plt.title("Trace of inverse of Fisher information matrix")
plt.grid()
plt.show()

plt.plot(data[10], data[2] - data[6], marker = 'o')
#plt.semilogy()
#plt.semilogx()
plt.xlabel("Number of states")
plt.ylabel("Trace")
plt.title("Trace of covariance matrix minus trace of inverse of Fisher information matrix")
plt.grid()
plt.show()

plt.plot(data[10], data[3], marker = 'o')
#plt.semilogy()
#plt.semilogx()
plt.xlabel("Number of states")
plt.ylabel("Eigenvalues")
plt.title("Eigenvalues of covariance matrix minus inverse of Fisher information matrix")
plt.grid()
plt.show()

plt.plot(data[10], np.log(np.linalg.det(data[5])), marker = 'o')
plt.semilogy()
#plt.semilogx()
plt.xlabel("Number of states")
plt.ylabel("Log Determinant")
plt.title("Log of determinant of Fisher information matrix")
plt.grid()
plt.show()

for i in range(data[0].shape[1]):
    plt.errorbar(data[10], data[0][:,i], yerr = data[12][:,i], label = f"Bias for $\omega_{i+1}$", marker = 'o')
#plt.semilogx()
plt.xlabel("Number of states")
plt.ylabel("Bias")
plt.title("Estimator bias")
plt.legend()
plt.grid()
plt.show()

plt.plot(data[10], data[2] + np.linalg.norm(data[0], axis=1)**2, marker = 'o')
plt.xlabel("Number of states")
plt.ylabel("MSE")
plt.semilogy()
plt.title("Mean Squared Error (MSE) vs Number of States")
plt.grid()
plt.show()

for i in range(len(data[10])):
    plt.plot(data[8], data[7][i], label='FIM Shannon Entropy')
    plt.plot(data[8], np.full(data[7][i].shape, np.log(3)), label='Max Entropy')
    plt.title(f"Number of states = {data[10][i]}")
    plt.xlabel('Evolution Time $\Omega t$')
    plt.ylabel('Shannon Entropy')
    plt.legend()
    plt.grid()
    plt.show()

# %% [markdown]
# Protocol B (Platonic Solids)

# %% [markdown]
# Data 0

# %%
files_0_b_ps = glob.glob('C:/Users/alexg/python_scripts/protocol_B/data_0_protocol_B_ps_1/*.npy')
data_0_b_ps = [np.load(f) for f in files_0_b_ps]
with open('C:/Users/alexg/python_scripts/protocol_B/data_0_protocol_B_ps_1/parameters.txt', "r") as f:
    parameters_data_0_b_ps = f.read()
print(parameters_data_0_b_ps)
print("Runtime per run (s): ", data_0_b_ps[12])
# Out:
# Parameters: J = 4.5; w = [ 0.00876437 -0.00440192  0.00752725]; sn_sd = 0.100; delta_t = 0.001; t_steps = 7000; iter = 500; Initial observable = J_y
# Runtime per run (s):  [3048.46337056 1706.27437139 8146.52839255 4338.54703522 1720.39055896]

# %%
data = data_0_b_ps
N_points = [4,6,8,12,20]
plt.plot(N_points, data[8], marker = 'o')
plt.semilogy()
#plt.semilogx()
plt.xlabel("Number of points")
plt.ylabel("Infidelity")
plt.title("Infidelity between inverse of Fisher information and covariance matrix")
plt.grid()
plt.show()

plt.plot(N_points, data[5], marker = 'o')
plt.semilogy()
#plt.semilogx()
plt.xlabel("Number of points")
plt.ylabel("Trace")
plt.title("Trace of inverse of Fisher information matrix")
plt.grid()
plt.show()

# plt.plot(N_points, data[2] - data[5], marker = 'o')
# #plt.semilogy()
# #plt.semilogx()
# plt.xlabel("Number of points")
# plt.ylabel("Trace")
# plt.title("Trace of covariance matrix minus trace of inverse of Fisher information matrix")
# plt.grid()
# plt.show()

# plt.plot(N_points, data[3], marker = 'o')
# #plt.semilogy()
# #plt.semilogx()
# plt.xlabel("Number of points")
# plt.ylabel("Eigenvalues")
# plt.title("Eigenvalues of covariance matrix minus inverse of Fisher information matrix")
# plt.grid()
# plt.show()

plt.plot(N_points, np.log(np.linalg.det(data[4])), marker = 'o')
plt.semilogy()
#plt.semilogx()
plt.xlabel("Number of points")
plt.ylabel("Log Determinant")
plt.title("Log of determinant of Fisher information matrix")
plt.grid()
plt.show()

for i in range(data[0].shape[1]):
    plt.errorbar(N_points, data[0][:,i], yerr = data[13][:,i], label = f"Bias for $\omega_{i+1}$", marker = 'o')
#plt.semilogx()
plt.xlabel("Number of points")
plt.ylabel("Bias")
plt.title("Estimator bias")
plt.legend()
plt.grid()
plt.show()

plt.plot(N_points, np.sum(data[10], axis=1), marker = 'o')
plt.xlabel("Number of points")
plt.ylabel("MSE")
plt.semilogy()
plt.title("Mean Squared Error (MSE) vs Number of Points")
plt.grid()
plt.show()

for i in range(len(data[11])):
    plt.plot(data[7], data[6][i], label='FIM Shannon Entropy')
    plt.plot(data[7], np.full(data[6][i].shape, np.log(3)), label='Max Entropy')
    plt.title(f"Number of points = {N_points[i]:.2f}")
    plt.xlabel('Evolution Time $\Omega t$')
    plt.ylabel('Shannon Entropy')
    plt.legend()
    plt.grid()
    plt.show()

# %% [markdown]
# Data 1 Platonic solids (Averaged over 10 choices of $\vec{\omega}$)

# %%
data_1_b_ps = load_npy('C:/Users/alexg/python_scripts/protocol_B/data_1_protocol_B_ps/')
print(len(data_1_b_ps))
# Out:
# 140

# %%
infidelity = [data_1_b_ps[8+i*14] for i in range(10)]
inv_fisher_trace = [data_1_b_ps[5+i*14] for i in range(10)]
mse = [np.sum(data_1_b_ps[10+i*14], axis = 1) for i in range(10)]
log_det_fisher = [np.log(np.linalg.det(data_1_b_ps[4+i*14])) for i in range(10)]
bias = [data_1_b_ps[i*14] for i in range(10)]
N_points = [4,6,8,12,20]

mean_infidelity = np.mean(infidelity, axis=0)
std_infidelity = np.std(infidelity, axis=0)
mean_inv_fisher_trace = np.mean(inv_fisher_trace, axis=0)
std_inv_fisher_trace = np.std(inv_fisher_trace, axis=0)
mean_mse = np.mean(mse, axis=0)
std_mse = np.std(mse, axis=0)
mean_log_det_fisher = np.mean(log_det_fisher, axis=0)
std_log_det_fisher = np.std(log_det_fisher, axis=0)
mean_bias = np.mean(bias, axis=0)
std_bias = np.std(bias, axis=0)

# %%
N_points = [4,6,8,12,20]
plt.errorbar(N_points, mean_infidelity, yerr=std_infidelity, marker='o')
plt.semilogy()
#plt.semilogx()
plt.xlabel("Number of points")
plt.ylabel("Infidelity")
plt.title("Infidelity between inverse of Fisher information and covariance matrix")
plt.grid()
plt.show()

plt.errorbar(N_points, mean_inv_fisher_trace, yerr=std_inv_fisher_trace, marker='o')
plt.semilogy()
#plt.semilogx()
plt.xlabel("Number of points")
plt.ylabel("Trace")
plt.title("Trace of inverse of Fisher information matrix")
plt.grid()
plt.show()

# plt.plot(N_points, data[2] - data[5], marker = 'o')
# #plt.semilogy()
# #plt.semilogx()
# plt.xlabel("Number of points")
# plt.ylabel("Trace")
# plt.title("Trace of covariance matrix minus trace of inverse of Fisher information matrix")
# plt.grid()
# plt.show()

# plt.plot(N_points, data[3], marker = 'o')
# #plt.semilogy()
# #plt.semilogx()
# plt.xlabel("Number of points")
# plt.ylabel("Eigenvalues")
# plt.title("Eigenvalues of covariance matrix minus inverse of Fisher information matrix")
# plt.grid()
# plt.show()

plt.errorbar(N_points, mean_log_det_fisher, yerr=std_log_det_fisher, marker='o')
plt.semilogy()
#plt.semilogx()
plt.xlabel("Number of points")
plt.ylabel("Log Determinant")
plt.title("Log of determinant of Fisher information matrix")
plt.grid()
plt.show()

for i in range(mean_bias.shape[1]):
    plt.errorbar(N_points, mean_bias[:,i], yerr = std_bias[:,i], label = f"Bias for $\omega_{i+1}$", marker = 'o')
#plt.semilogx()
plt.xlabel("Number of points")
plt.ylabel("Bias")
plt.title("Estimator bias")
plt.legend()
plt.grid()
plt.show()

plt.errorbar(N_points, mean_mse, yerr=std_mse, marker = 'o')
plt.xlabel("Number of points")
plt.ylabel("MSE")
plt.semilogy()
plt.title("Mean Squared Error (MSE) vs Number of Points")
plt.grid()
plt.show()

# for i in range(len(data[11])):
#     plt.plot(data[7], data[6][i], label='FIM Shannon Entropy')
#     plt.plot(data[7], np.full(data[6][i].shape, np.log(3)), label='Max Entropy')
#     plt.title(f"Number of points = {N_points[i]:.2f}")
#     plt.xlabel('Evolution Time $\Omega t$')
#     plt.ylabel('Shannon Entropy')
#     plt.legend()
#     plt.grid()
#     plt.show()

# %% [markdown]
# Data 0 Fibonacci lattice (Averaged over 6 choices of $\vec{\omega}$)

# %%
data_0_b_fl = load_npy('C:/Users/alexg/python_scripts/protocol_B/data_0_protocol_B_fl/')
print(len(data_0_b_fl))
# Out:
# 84

# %%
infidelity = [data_0_b_fl[8+i*14] for i in range(6)]
inv_fisher_trace = [data_0_b_fl[5+i*14] for i in range(6)]
mse = [np.sum(data_0_b_fl[10+i*14], axis = 1) for i in range(6)]
log_det_fisher = [np.log(np.linalg.det(data_0_b_fl[4+i*14])) for i in range(6)]
bias = [data_0_b_fl[i*14] for i in range(6)]
N_points = np.arange(4, 40, 4)

mean_infidelity = np.mean(infidelity, axis=0)
std_infidelity = np.std(infidelity, axis=0)
mean_inv_fisher_trace = np.mean(inv_fisher_trace, axis=0)
std_inv_fisher_trace = np.std(inv_fisher_trace, axis=0)
mean_mse = np.mean(mse, axis=0)
std_mse = np.std(mse, axis=0)
mean_log_det_fisher = np.mean(log_det_fisher, axis=0)
std_log_det_fisher = np.std(log_det_fisher, axis=0)
mean_bias = np.mean(bias, axis=0)
std_bias = np.std(bias, axis=0)

# %%
plt.errorbar(N_points, mean_infidelity, yerr=std_infidelity, marker='o')
plt.semilogy()
#plt.semilogx()
plt.xlabel("Number of points")
plt.ylabel("Infidelity")
plt.title("Infidelity between inverse of Fisher information and covariance matrix")
plt.grid()
plt.show()

plt.errorbar(N_points, mean_inv_fisher_trace, yerr=std_inv_fisher_trace, marker='o')
plt.semilogy()
#plt.semilogx()
plt.xlabel("Number of points")
plt.ylabel("Trace")
plt.title("Trace of inverse of Fisher information matrix")
plt.grid()
plt.show()

plt.errorbar(N_points, mean_log_det_fisher, yerr=std_log_det_fisher, marker='o')
plt.semilogy()
#plt.semilogx()
plt.xlabel("Number of points")
plt.ylabel("Log Determinant")
plt.title("Log of determinant of Fisher information matrix")
plt.grid()
plt.show()

for i in range(mean_bias.shape[1]):
    plt.errorbar(N_points, mean_bias[:,i], yerr = std_bias[:,i], label = f"Bias for $\omega_{i+1}$", marker = 'o')
#plt.semilogx()
plt.xlabel("Number of points")
plt.ylabel("Bias")
plt.title("Estimator bias")
plt.legend()
plt.grid()
plt.show()

plt.errorbar(N_points, mean_mse, yerr=std_mse, marker = 'o')
plt.xlabel("Number of points")
plt.ylabel("MSE")
plt.semilogy()
plt.title("Mean Squared Error (MSE) vs Number of Points")
plt.grid()
plt.show()

# for i in range(len(data[11])):
#     plt.plot(data[7], data[6][i], label='FIM Shannon Entropy')
#     plt.plot(data[7], np.full(data[6][i].shape, np.log(3)), label='Max Entropy')
#     plt.title(f"Number of points = {N_points[i]:.2f}")
#     plt.xlabel('Evolution Time $\Omega t$')
#     plt.ylabel('Shannon Entropy')
#     plt.legend()
#     plt.grid()
#     plt.show()

# %% [markdown]
# Data trotter 16 (random phases every 1000 time steps, prior for $\vec{\omega}$ has stdev of 0.01)

# %%
files_t_16 = glob.glob('C:/Users/alexg/python_scripts/corrected_FI_code/trotter/data_trotter_16/*.npy')
data_t_16 = [np.load(f) for f in files_t_16]
with open('C:/Users/alexg/python_scripts/corrected_FI_code/trotter/data_trotter_16/parameters.txt', "r") as f:
    parameters_data_t_16 = f.read()
print(parameters_data_t_16)
print("Runtime per run (s): ", data_t_16[12])
# Out:
# Parameters: J = 4.5; beta = 10.000; omega = 1; w = [ 0.00189053 -0.00522748 -0.00413064]; sn_sd = 0.100; delta_t = 0.001; t_steps = 7000; iter = 500; random_phase_steps = 1000;  gtol = 1e-05; Initial state: theta_scs = 1.571; phi_scs = 0.000; Initial observable = J_y
# Runtime per run (s):  [ 3254.81505179 10187.62301016  1403.90936613  1553.22108436
#   1035.22459126  1854.86893797   568.58138871  1017.23992276
#   1579.84548712  1807.7043786   1073.45327902]

# %%
data = data_t_16
plt.plot(data[0], data[9], marker = 'o')
#plt.semilogy()
#plt.semilogx()
plt.xlabel("Beta")
plt.ylabel("Infidelity")
plt.title("Infidelity between inverse of Fisher information and covariance matrix")
plt.grid()
plt.show()

plt.plot(data[0], data[6], marker = 'o')
#plt.semilogy()
#plt.semilogx()
plt.xlabel("Beta")
plt.ylabel("Trace")
plt.title("Trace of inverse of Fisher information matrix")
plt.grid()
plt.show()

# plt.plot(data[0], data[3] - data[6], marker = 'o')
# #plt.semilogy()
# #plt.semilogx()
# plt.xlabel("Beta")
# plt.ylabel("Trace")
# plt.title("Trace of covariance matrix minus trace of inverse of Fisher information matrix")
# plt.grid()
# plt.show()

# plt.plot(data[0], data[4], marker = 'o')
# #plt.semilogy()
# #plt.semilogx()
# plt.xlabel("Beta")
# plt.ylabel("Eigenvalues")
# plt.title("Eigenvalues of covariance matrix minus inverse of Fisher information matrix")
# plt.grid()
# plt.show()

plt.plot(data[0], np.log(np.linalg.det(data[5])), marker = 'o')
plt.semilogy()
#plt.semilogx()
plt.xlabel("Beta")
plt.ylabel("Log Determinant")
plt.title("Log of determinant of Fisher information matrix")
plt.grid()
plt.show()

for i in range(data[1].shape[1]):
    plt.errorbar(data[0], data[1][:,i], yerr = data[13][:,i], label = f"Bias for $\omega_{i+1}$", marker = 'o')
#plt.semilogx()
plt.xlabel("Beta")
plt.ylabel("Bias")
plt.title("Estimator bias")
plt.legend()
plt.grid()
plt.show()

plt.plot(data[0], np.sum(data[11], axis=1), marker = 'o')
plt.xlabel("Beta")
plt.ylabel("MSE")
#plt.semilogy()
plt.title("Mean Squared Error (MSE) vs Beta")
plt.grid()
plt.show()

# for i in range(len(data[0])):
#     plt.plot(data[8], data[7][i], label='FIM Shannon Entropy')
#     plt.plot(data[8], np.full(data[7][i].shape, np.log(3)), label='Max Entropy')
#     plt.title(f"Beta = {data[0][i]:.2f}")
#     plt.xlabel('Evolution Time $\Omega t$')
#     plt.ylabel('Shannon Entropy')
#     plt.legend()
#     plt.grid()
#     plt.show()

# %% [markdown]
# Data trotter linearized 0 (stdev of $\vec{\omega}$ is 0.01)

# %%
files_tl_0 = glob.glob('C:/Users/alexg/python_scripts/corrected_FI_code/trotter_linearized/laptop_0.01/*.npy')
data_tl_0 = [np.load(f) for f in files_tl_0]
with open('C:/Users/alexg/python_scripts/corrected_FI_code/trotter_linearized/laptop_0.01/parameters.txt', "r") as f:
    parameters_data_tl_0 = f.read()
print(parameters_data_tl_0)
print("Runtime per run (s): ", data_tl_0[12])
# Out:
# Parameters: J = 4.5; beta = 10.000; omega = 1; w = [ 0.00189053 -0.00522748 -0.00413064]; sn_sd = 0.100; delta_t = 0.001; t_steps = 7000; iter = 500; random_phase_steps = 1000;  gtol = 1e-05; Initial state: theta_scs = 1.571; phi_scs = 0.000; Initial observable = J_y
# Runtime per run (s):  [236.68402123 245.80017281 256.39771032 267.64728093 265.13510489
#  274.02220416 257.02082038 244.70670485 267.47533965 278.50557113
#  273.78660011]

# %%
data = data_tl_0
plt.plot(data[0], data[9], marker = 'o')
plt.semilogy()
#plt.semilogx()
plt.xlabel("Beta")
plt.ylabel("Infidelity")
plt.title("Infidelity between inverse of Fisher information and covariance matrix")
plt.grid()
plt.show()

plt.plot(data[0], data[6], marker = 'o')
#plt.semilogy()
#plt.semilogx()
plt.xlabel("Beta")
plt.ylabel("Trace")
plt.title("Trace of inverse of Fisher information matrix")
plt.grid()
plt.show()

plt.plot(data[0], data[3] - data[6], marker = 'o')
#plt.semilogy()
#plt.semilogx()
plt.xlabel("Beta")
plt.ylabel("Trace")
plt.title("Trace of covariance matrix minus trace of inverse of Fisher information matrix")
plt.grid()
plt.show()

plt.plot(data[0], data[4], marker = 'o')
#plt.semilogy()
#plt.semilogx()
plt.xlabel("Beta")
plt.ylabel("Eigenvalues")
plt.title("Eigenvalues of covariance matrix minus inverse of Fisher information matrix")
plt.grid()
plt.show()

plt.plot(data[0], np.log(np.linalg.det(data[5])), marker = 'o')
plt.semilogy()
#plt.semilogx()
plt.xlabel("Beta")
plt.ylabel("Log Determinant")
plt.title("Log of determinant of Fisher information matrix")
plt.grid()
plt.show()

for i in range(data[1].shape[1]):
    plt.errorbar(data[0], data[1][:,i], yerr = data[13][:,i], label = f"Bias for $\omega_{i+1}$", marker = 'o')
#plt.semilogx()
plt.xlabel("Beta")
plt.ylabel("Bias")
plt.title("Estimator bias")
plt.legend()
plt.grid()
plt.show()

plt.plot(data[0], np.sum(data[11], axis=1), marker = 'o')
plt.xlabel("Beta")
plt.ylabel("MSE")
plt.semilogy()
plt.title("Mean Squared Error (MSE) vs Beta")
plt.grid()
plt.show()

for i in range(len(data[0])):
    plt.plot(data[8], data[7][i], label='FIM Shannon Entropy')
    plt.plot(data[8], np.full(data[7][i].shape, np.log(3)), label='Max Entropy')
    plt.title(f"Beta = {data[0][i]:.2f}")
    plt.xlabel('Evolution Time $\Omega t$')
    plt.ylabel('Shannon Entropy')
    plt.legend()
    plt.grid()
    plt.show()

# %% [markdown]
# Data trotter linearized 1 ($\vec{\omega}$ with stdev of 0.1 run on laptop)

# %%
files_tl_1 = glob.glob('C:/Users/alexg/python_scripts/corrected_FI_code/trotter_linearized/laptop_0.1/*.npy')
data_tl_1 = [np.load(f) for f in files_tl_1]
with open('C:/Users/alexg/python_scripts/corrected_FI_code/trotter_linearized/laptop_0.1/parameters.txt', "r") as f:
    parameters_data_tl_1 = f.read()
print(parameters_data_tl_1)
print("Runtime per run (s): ", data_tl_1[12])
# Out:
# Parameters: J = 4.5; beta = 10.000; omega = 1; w = [0.03455842 0.08216181 0.03304371]; sn_sd = 0.100; delta_t = 0.001; t_steps = 7000; iter = 500; random_phase_steps = 1000;  gtol = 1e-05; Initial state: theta_scs = 1.571; phi_scs = 0.000; Initial observable = J_y
# Runtime per run (s):  [235.06410599 276.03503132 249.76622605 244.40048432 263.98749328
#  318.28813386 352.96815491 362.84795737 319.65101957 405.7371161
#  242.98505306]

# %%
data = data_tl_1
plt.plot(data[0], data[9], marker = 'o')
plt.semilogy()
#plt.semilogx()
plt.xlabel("Beta")
plt.ylabel("Infidelity")
plt.title("Infidelity between inverse of Fisher information and covariance matrix")
plt.grid()
plt.show()

plt.plot(data[0], data[6], marker = 'o')
plt.semilogy()
#plt.semilogx()
plt.xlabel("Beta")
plt.ylabel("Trace")
plt.title("Trace of inverse of Fisher information matrix")
plt.grid()
plt.show()

plt.plot(data[0], data[3] - data[6], marker = 'o')
#plt.semilogy()
#plt.semilogx()
plt.xlabel("Beta")
plt.ylabel("Trace")
plt.title("Trace of covariance matrix minus trace of inverse of Fisher information matrix")
plt.grid()
plt.show()

plt.plot(data[0], data[4], marker = 'o')
#plt.semilogy()
#plt.semilogx()
plt.xlabel("Beta")
plt.ylabel("Eigenvalues")
plt.title("Eigenvalues of covariance matrix minus inverse of Fisher information matrix")
plt.grid()
plt.show()

plt.plot(data[0], np.log(np.linalg.det(data[5])), marker = 'o')
plt.semilogy()
#plt.semilogx()
plt.xlabel("Beta")
plt.ylabel("Log Determinant")
plt.title("Log of determinant of Fisher information matrix")
plt.grid()
plt.show()

for i in range(data[1].shape[1]):
    plt.errorbar(data[0], data[1][:,i], yerr = data[13][:,i], label = f"Bias for $\omega_{i+1}$", marker = 'o')
#plt.semilogx()
plt.xlabel("Beta")
plt.ylabel("Bias")
plt.title("Estimator bias")
plt.legend()
plt.grid()
plt.show()

plt.plot(data[0], np.sum(data[11], axis=1), marker = 'o')
plt.xlabel("Beta")
plt.ylabel("MSE")
plt.semilogy()
plt.title("Mean Squared Error (MSE) vs Beta")
plt.grid()
plt.show()

for i in range(len(data[0])):
    plt.plot(data[8], data[7][i], label='FIM Shannon Entropy')
    plt.plot(data[8], np.full(data[7][i].shape, np.log(3)), label='Max Entropy')
    plt.title(f"Beta = {data[0][i]:.2f}")
    plt.xlabel('Evolution Time $\Omega t$')
    plt.ylabel('Shannon Entropy')
    plt.legend()
    plt.grid()
    plt.show()

# %% [markdown]
# Data trotter linearized 2 ($\vec{\omega}$ stdev = 0.1)

# %%
files_tl_2 = glob.glob('C:/Users/alexg/python_scripts/corrected_FI_code/trotter_linearized/data_trotter_linearized_0.1/*.npy')
data_tl_2 = [np.load(f) for f in files_tl_2]
with open('C:/Users/alexg/python_scripts/corrected_FI_code/trotter_linearized/data_trotter_linearized_0.1/parameters.txt', "r") as f:
    parameters_data_tl_2 = f.read()
print(parameters_data_tl_2)
print("Runtime per run (s): ", data_tl_2[12])
# Out:
# Parameters: J = 4.5; beta = 10.000; omega = 1; w = [0.03455842 0.08216181 0.03304371]; sn_sd = 0.100; delta_t = 0.001; t_steps = 7000; iter = 500; random_phase_steps = 1000;  gtol = 1e-05; Initial state: theta_scs = 1.571; phi_scs = 0.000; Initial observable = J_y
# Runtime per run (s):  [95.53395677 94.71139932 94.77727485 94.78131866 94.81432295 94.82462621
#  95.0694592  95.01610899 95.29524541 95.32061982 94.90286112]

# %%
data = data_tl_2
plt.plot(data[0], data[9], marker = 'o')
plt.semilogy()
#plt.semilogx()
plt.xlabel("Beta")
plt.ylabel("Infidelity")
plt.title("Infidelity between inverse of Fisher information and covariance matrix")
plt.grid()
plt.show()

plt.plot(data[0], data[6], marker = 'o')
plt.semilogy()
#plt.semilogx()
plt.xlabel("Beta")
plt.ylabel("Trace")
plt.title("Trace of inverse of Fisher information matrix")
plt.grid()
plt.show()

# plt.plot(data[0], data[3] - data[6], marker = 'o')
# #plt.semilogy()
# #plt.semilogx()
# plt.xlabel("Beta")
# plt.ylabel("Trace")
# plt.title("Trace of covariance matrix minus trace of inverse of Fisher information matrix")
# plt.grid()
# plt.show()

# plt.plot(data[0], data[4], marker = 'o')
# #plt.semilogy()
# #plt.semilogx()
# plt.xlabel("Beta")
# plt.ylabel("Eigenvalues")
# plt.title("Eigenvalues of covariance matrix minus inverse of Fisher information matrix")
# plt.grid()
# plt.show()

plt.plot(data[0], np.log(np.linalg.det(data[5])), marker = 'o')
plt.semilogy()
#plt.semilogx()
plt.xlabel("Beta")
plt.ylabel("Log Determinant")
plt.title("Log of determinant of Fisher information matrix")
plt.grid()
plt.show()

for i in range(data[1].shape[1]):
    plt.errorbar(data[0], data[1][:,i], yerr = data[13][:,i], label = f"Bias for $\omega_{i+1}$", marker = 'o')
#plt.semilogx()
plt.xlabel("Beta")
plt.ylabel("Bias")
plt.title("Estimator bias")
plt.legend()
plt.grid()
plt.show()

plt.plot(data[0], np.sum(data[11], axis=1), marker = 'o')
plt.xlabel("Beta")
plt.ylabel("MSE")
plt.semilogy()
plt.title("Mean Squared Error (MSE) vs Beta")
plt.grid()
plt.show()

# for i in range(len(data[0])):
#     plt.plot(data[8], data[7][i], label='FIM Shannon Entropy')
#     plt.plot(data[8], np.full(data[7][i].shape, np.log(3)), label='Max Entropy')
#     plt.title(f"Beta = {data[0][i]:.2f}")
#     plt.xlabel('Evolution Time $\Omega t$')
#     plt.ylabel('Shannon Entropy')
#     plt.legend()
#     plt.grid()
#     plt.show()

# %% [markdown]
# Data trotter least squares 0 ($\vec{\omega}$ stdev = 0.1)

# %%
files_ls_0 = glob.glob('C:/Users/alexg/python_scripts/corrected_FI_code/trotter_linearized/data_trotter_least_squares_0.1/*.npy')
data_ls_0 = [np.load(f) for f in files_ls_0]
with open('C:/Users/alexg/python_scripts/corrected_FI_code/trotter_linearized/data_trotter_least_squares_0.1/parameters.txt', "r") as f:
    parameters_data_ls_0 = f.read()
print(parameters_data_ls_0)
print("Runtime per run (s): ", data_ls_0[12])
# Out:
# Parameters: J = 4.5; beta = 10.000; omega = 1; w = [0.03455842 0.08216181 0.03304371]; sn_sd = 0.100; delta_t = 0.001; t_steps = 7000; iter = 500; random_phase_steps = 1000; Initial state: theta_scs = 1.571; phi_scs = 0.000; Initial observable = J_y
# Runtime per run (s):  [105.31170964 107.48225284 107.4320004  109.01616597 110.35425687
#  110.66106272 110.02134275 107.80037999 106.97364521 104.6291995
#  107.6545639 ]

# %%
data = data_ls_0
plt.plot(data[0], data[9], marker = 'o')
plt.semilogy()
#plt.semilogx()
plt.xlabel("Beta")
plt.ylabel("Infidelity")
plt.title("Infidelity between inverse of Fisher information and covariance matrix")
plt.grid()
plt.show()

plt.plot(data[0], data[6], marker = 'o')
plt.semilogy()
#plt.semilogx()
plt.xlabel("Beta")
plt.ylabel("Trace")
plt.title("Trace of inverse of Fisher information matrix")
plt.grid()
plt.show()

# plt.plot(data[0], data[3] - data[6], marker = 'o')
# #plt.semilogy()
# #plt.semilogx()
# plt.xlabel("Beta")
# plt.ylabel("Trace")
# plt.title("Trace of covariance matrix minus trace of inverse of Fisher information matrix")
# plt.grid()
# plt.show()

# plt.plot(data[0], data[4], marker = 'o')
# #plt.semilogy()
# #plt.semilogx()
# plt.xlabel("Beta")
# plt.ylabel("Eigenvalues")
# plt.title("Eigenvalues of covariance matrix minus inverse of Fisher information matrix")
# plt.grid()
# plt.show()

plt.plot(data[0], np.log(np.linalg.det(data[5])), marker = 'o')
plt.semilogy()
#plt.semilogx()
plt.xlabel("Beta")
plt.ylabel("Log Determinant")
plt.title("Log of determinant of Fisher information matrix")
plt.grid()
plt.show()

for i in range(data[1].shape[1]):
    plt.errorbar(data[0], data[1][:,i], yerr = data[13][:,i], label = f"Bias for $\omega_{i+1}$", marker = 'o')
#plt.semilogx()
plt.xlabel("Beta")
plt.ylabel("Bias")
plt.title("Estimator bias")
plt.legend()
plt.grid()
plt.show()

plt.plot(data[0], np.sum(data[11], axis=1), marker = 'o')
plt.xlabel("Beta")
plt.ylabel("MSE")
plt.semilogy()
plt.title("Mean Squared Error (MSE) vs Beta")
plt.grid()
plt.show()

# for i in range(len(data[0])):
#     plt.plot(data[8], data[7][i], label='FIM Shannon Entropy')
#     plt.plot(data[8], np.full(data[7][i].shape, np.log(3)), label='Max Entropy')
#     plt.title(f"Beta = {data[0][i]:.2f}")
#     plt.xlabel('Evolution Time $\Omega t$')
#     plt.ylabel('Shannon Entropy')
#     plt.legend()
#     plt.grid()
#     plt.show()
